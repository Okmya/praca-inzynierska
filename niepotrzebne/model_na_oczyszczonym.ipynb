# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import matplotlib.pyplot as plt

# hyperparameters
batch_size = 32  # how many independent sequences will we process in parallel?
block_size = 64  # maximum context length for predictions
max_iters = 12000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.1

# dynamic block_size adjustment for GPU memory
#if device == 'cuda':
#device = "cuda"
gpu_memory = torch.cuda.get_device_properties(0).total_memory
block_size = min(128, max(16, gpu_memory // (n_embd * 1024)))

torch.manual_seed(166045)

# Load text data
with open('pan_tadeusz_oczyszczony.txt', 'r', encoding='utf-8') as f:
    text = f.read()

chars = sorted(list(set(text)))
vocab_size = len(chars)
stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for i, ch in enumerate(chars)}
encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join([itos[i] for i in l])

data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

def get_batch(split, seq_sampling=False):
    data = train_data if split == 'train' else val_data
    if seq_sampling:
        start_idx = torch.randint(0, len(data) - block_size, (1,)).item()
        x = data[start_idx:start_idx + block_size].unsqueeze(0).repeat(batch_size, 1)
        y = data[start_idx + 1:start_idx + block_size + 1].unsqueeze(0).repeat(batch_size, 1)
    else:
        ix = torch.randint(len(data) - block_size, (batch_size,))
        x = torch.stack([data[i:i + block_size] for i in ix])
        y = torch.stack([data[i + 1:i + block_size + 1] for i in ix])
    return x.to(device), y.to(device)

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)
        wei = q @ k.transpose(-2, -1) * C**-0.5
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        out = wei @ v
        return out

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedForward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.dropout = nn.Dropout(0.1)

    def forward(self, x):
        x = x + self.dropout(self.sa(self.ln1(x)))
        x = x + self.dropout(self.ffwd(self.ln2(x)))
        return x

class GPTModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = tok_emb + pos_emb
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B * T, C)
            targets = targets.view(B * T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens, temperature=1.0):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, _ = self(idx_cond)
            logits = logits[:, -1, :] / temperature
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

model = GPTModel().to(device)
print(sum(p.numel() for p in model.parameters()) / 1e6, 'M parameters')

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

train_losses, val_losses = [], []

for iter in range(max_iters):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses.append(losses['train'])
        val_losses.append(losses['val'])
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    xb, yb = get_batch('train')
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.legend()
plt.xlabel('Evaluation Interval')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.show()

context = torch.zeros((1, 1), dtype=torch.long, device=device)
generated_text = decode(model.generate(context, max_new_tokens=2000)[0].tolist())

with open('wynik_oczyszczony.txt', 'w', encoding='utf-8') as f:
    f.write(generated_text)
# Out:
# 0.214454 M parameters
# step 0: train loss 4.2085, val loss 4.2134
# step 100: train loss 2.6483, val loss 2.6469
# step 200: train loss 2.5750, val loss 2.5752
# step 300: train loss 2.5444, val loss 2.5466
# step 400: train loss 2.5244, val loss 2.5235
# step 500: train loss 2.4979, val loss 2.4960
# step 600: train loss 2.4723, val loss 2.4761
# step 700: train loss 2.4410, val loss 2.4457
# step 800: train loss 2.4022, val loss 2.4063
# step 900: train loss 2.3693, val loss 2.3733
# step 1000: train loss 2.3307, val loss 2.3386
# step 1100: train loss 2.2970, val loss 2.3141
# step 1200: train loss 2.2692, val loss 2.2907
# step 1300: train loss 2.2534, val loss 2.2741
# step 1400: train loss 2.2253, val loss 2.2485
# step 1500: train loss 2.2147, val loss 2.2302
# step 1600: train loss 2.1964, val loss 2.2204
# step 1700: train loss 2.1809, val loss 2.2019
# step 1800: train loss 2.1606, val loss 2.1895
# step 1900: train loss 2.1461, val loss 2.1693
# step 2000: train loss 2.1321, val loss 2.1663
# step 2100: train loss 2.1161, val loss 2.1500
# step 2200: train loss 2.1007, val loss 2.1335
# step 2300: train loss 2.0917, val loss 2.1250
# step 2400: train loss 2.0808, val loss 2.1143
# step 2500: train loss 2.0684, val loss 2.0987
# step 2600: train loss 2.0507, val loss 2.0916
# step 2700: train loss 2.0400, val loss 2.0751
# step 2800: train loss 2.0309, val loss 2.0693
# step 2900: train loss 2.0201, val loss 2.0582
# step 3000: train loss 2.0134, val loss 2.0529
# step 3100: train loss 1.9999, val loss 2.0413
# step 3200: train loss 1.9900, val loss 2.0346
# step 3300: train loss 1.9806, val loss 2.0197
# step 3400: train loss 1.9765, val loss 2.0188
# step 3500: train loss 1.9619, val loss 2.0139
# step 3600: train loss 1.9559, val loss 2.0041
# step 3700: train loss 1.9491, val loss 1.9969
# step 3800: train loss 1.9432, val loss 1.9946
# step 3900: train loss 1.9349, val loss 1.9838
# step 4000: train loss 1.9293, val loss 1.9814
# step 4100: train loss 1.9212, val loss 1.9723
# step 4200: train loss 1.9168, val loss 1.9706
# step 4300: train loss 1.9097, val loss 1.9656
# step 4400: train loss 1.9062, val loss 1.9623
# step 4500: train loss 1.9000, val loss 1.9581
# step 4600: train loss 1.8936, val loss 1.9469
# step 4700: train loss 1.8882, val loss 1.9451
# step 4800: train loss 1.8817, val loss 1.9405
# step 4900: train loss 1.8821, val loss 1.9368
# step 5000: train loss 1.8729, val loss 1.9290
# step 5100: train loss 1.8671, val loss 1.9292
# step 5200: train loss 1.8630, val loss 1.9207
# step 5300: train loss 1.8623, val loss 1.9212
# step 5400: train loss 1.8570, val loss 1.9229
# step 5500: train loss 1.8499, val loss 1.9145
# step 5600: train loss 1.8463, val loss 1.9141
# step 5700: train loss 1.8482, val loss 1.9133
# step 5800: train loss 1.8362, val loss 1.9010
# step 5900: train loss 1.8354, val loss 1.9000
# step 6000: train loss 1.8298, val loss 1.8962
# step 6100: train loss 1.8288, val loss 1.8893
# step 6200: train loss 1.8249, val loss 1.8886
# step 6300: train loss 1.8220, val loss 1.8909
# step 6400: train loss 1.8164, val loss 1.8808
# step 6500: train loss 1.8121, val loss 1.8832
# step 6600: train loss 1.8113, val loss 1.8761
# step 6700: train loss 1.8051, val loss 1.8798
# step 6800: train loss 1.8029, val loss 1.8728
# step 6900: train loss 1.7996, val loss 1.8720
# step 7000: train loss 1.8006, val loss 1.8714
# step 7100: train loss 1.7973, val loss 1.8721
# step 7200: train loss 1.7938, val loss 1.8660
# step 7300: train loss 1.7938, val loss 1.8631
# step 7400: train loss 1.7922, val loss 1.8594
# step 7500: train loss 1.7825, val loss 1.8594
# step 7600: train loss 1.7783, val loss 1.8569
# step 7700: train loss 1.7791, val loss 1.8571
# step 7800: train loss 1.7780, val loss 1.8569
# step 7900: train loss 1.7695, val loss 1.8511
# step 8000: train loss 1.7729, val loss 1.8492
# step 8100: train loss 1.7688, val loss 1.8473
# step 8200: train loss 1.7679, val loss 1.8461
# step 8300: train loss 1.7664, val loss 1.8452
# step 8400: train loss 1.7610, val loss 1.8411
# step 8500: train loss 1.7606, val loss 1.8469
# step 8600: train loss 1.7630, val loss 1.8437
# step 8700: train loss 1.7585, val loss 1.8430
# step 8800: train loss 1.7525, val loss 1.8355
# step 8900: train loss 1.7547, val loss 1.8318
# step 9000: train loss 1.7480, val loss 1.8292
# step 9100: train loss 1.7467, val loss 1.8332
# step 9200: train loss 1.7453, val loss 1.8249
# step 9300: train loss 1.7448, val loss 1.8305
# step 9400: train loss 1.7415, val loss 1.8268
# step 9500: train loss 1.7388, val loss 1.8269
# step 9600: train loss 1.7395, val loss 1.8287
# step 9700: train loss 1.7364, val loss 1.8253
# step 9800: train loss 1.7344, val loss 1.8193
# step 9900: train loss 1.7343, val loss 1.8216
# step 10000: train loss 1.7368, val loss 1.8175
# step 10100: train loss 1.7299, val loss 1.8126
# step 10200: train loss 1.7288, val loss 1.8170
# step 10300: train loss 1.7269, val loss 1.8176
# step 10400: train loss 1.7270, val loss 1.8112
# step 10500: train loss 1.7262, val loss 1.8155
# step 10600: train loss 1.7236, val loss 1.8098
# step 10700: train loss 1.7267, val loss 1.8157
# step 10800: train loss 1.7169, val loss 1.8058
# step 10900: train loss 1.7186, val loss 1.8058
# step 11000: train loss 1.7213, val loss 1.8092
# step 11100: train loss 1.7183, val loss 1.8043
# step 11200: train loss 1.7136, val loss 1.8063
# step 11300: train loss 1.7079, val loss 1.7994
# step 11400: train loss 1.7133, val loss 1.8016
# step 11500: train loss 1.7118, val loss 1.8007
# step 11600: train loss 1.7088, val loss 1.7962
# step 11700: train loss 1.7091, val loss 1.7999
# step 11800: train loss 1.7040, val loss 1.7975
# step 11900: train loss 1.7044, val loss 1.7946
# step 11999: train loss 1.7022, val loss 1.7974

# %%
prompt = "Litwo, ojczyzno moja, Ty jesteś jak zdrowie..."
encoded_prompt = torch.tensor([encode(prompt)], dtype=torch.long, device=device)

# Encode: Zamienia tekst na tokeny
print("Encoded prompt:", encode(prompt))

# Decode: Zamienia tokeny na tekst
tokens = encode(prompt)
print("Decoded back to text:", decode(tokens))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 prompt = "Litwo, ojczyzno moja, Ty jesteś jak zdrowie..."
# ----> 2 encoded_prompt = torch.tensor([encode(prompt,"1")], dtype=torch.long, device=device)
#       4 # Encode: Zamienia tekst na tokeny
#       5 print("Encoded prompt:", encode(prompt))
#
# Cell In[5], line 5, in encode(text, tokenizer)
#       4 def encode(text, tokenizer):
# ----> 5     return torch.tensor(tokenizer.encode(text), dtype=torch.long).unsqueeze(0)
#
# LookupError: unknown encoding: Litwo, ojczyzno moja, Ty jesteś jak zdrowie...
