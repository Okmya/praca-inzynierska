# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

# Define a dictionary to hold the parameters
parametry = {
    "batch_size": 32,
    "block_size": 64,
    "max_iters": 10000,
    "eval_interval": 100,
    "learning_rate": 1e-3,
    "n_embd": 64,
    "n_head": 4,
    "n_layer": 4,
    "dropout": 0.1,
    "device": 'cuda' if torch.cuda.is_available() else 'cpu',
    "eval_iters": 200,
}


torch.manual_seed(166045)

# Adjust block_size dynamically based on available GPU memory
if parametry["device"] == "cuda":
    gpu_memory = torch.cuda.get_device_properties(0).total_memory
    parametry["block_size"] = min(128, max(16, gpu_memory // (parametry["n_embd"] * 1024)))

# Function to calculate perplexity
def perplexity(loss):
    return torch.exp(loss)

# Function to initialize hyperparameters from a dictionary
def initialize_params(params):
    globals().update(params)

# Initialize hyperparameters
initialize_params(parametry)

# Prepare the dataset
with open('pan-tadeusz.txt', 'r', encoding='utf-8') as f:
    text = f.read()

chars = sorted(list(set(text)))
vocab_size = len(chars)
stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for i, ch in enumerate(chars)}
encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join([itos[i] for i in l])

data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

def get_batch(split, seq_sampling=False):
    data = train_data if split == 'train' else val_data
    if seq_sampling:
        start_idx = torch.randint(0, len(data) - block_size, (1,)).item()
        x = data[start_idx:start_idx + block_size].unsqueeze(0).repeat(batch_size, 1)
        y = data[start_idx + 1:start_idx + block_size + 1].unsqueeze(0).repeat(batch_size, 1)
    else:
        ix = torch.randint(len(data) - block_size, (batch_size,))
        x = torch.stack([data[i:i + block_size] for i in ix])
        y = torch.stack([data[i + 1:i + block_size + 1] for i in ix])
    return x.to(device), y.to(device)

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)
        wei = q @ k.transpose(-2, -1) * C**-0.5
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        out = wei @ v
        return out


class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out


class Block(nn.Module):
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.dropout = nn.Dropout(0.1)

    def forward(self, x):
        x = x + self.dropout(self.sa(self.ln1(x)))
        x = x + self.dropout(self.ffwd(self.ln2(x)))
        return x

class GPTModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)



    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = tok_emb + pos_emb
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B * T, C)
            targets = targets.view(B * T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens, temperature=1.0):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, _ = self(idx_cond)
            logits = logits[:, -1, :] / temperature
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

# Initialize and train the model
model = GPTModel().to(device)
print(f"Model parameters: {sum(p.numel() for p in model.parameters()) / 1e6} M")

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

train_losses, val_losses, perplexities = [], [], []

for iter in range(max_iters):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses.append(losses['train'])
        val_losses.append(losses['val'])
        perplexities.append(perplexity(losses['val']).item())
        print(f"Step {iter}: Train loss {losses['train']:.4f}, Val loss {losses['val']:.4f}, Perplexity {perplexities[-1]:.4f}")

    xb, yb = get_batch('train')
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# Training loss plot
plt.figure()
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.legend()
plt.xlabel('Evaluation Interval')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.show()

# Perplexity plot
plt.figure()
plt.plot(perplexities, label='Perplexity')
plt.legend()
plt.xlabel('Evaluation Interval')
plt.ylabel('Perplexity')
plt.title('Validation Perplexity')
plt.show()

# Generate text
context = torch.zeros((1, 1), dtype=torch.long, device=device)
generated_text = decode(model.generate(context, max_new_tokens=2000)[0].tolist())

with open('generated_text.txt', 'w', encoding='utf-8') as f:
    f.write(generated_text)
# Out:
# Model parameters: 0.218324 M
# Step 0: Train loss 4.6690, Val loss 4.6694, Perplexity 106.6376
# Step 100: Train loss 2.7268, Val loss 2.7203, Perplexity 15.1854
# Step 200: Train loss 2.6026, Val loss 2.6010, Perplexity 13.4775
# Step 300: Train loss 2.5675, Val loss 2.5653, Perplexity 13.0048
# Step 400: Train loss 2.5481, Val loss 2.5479, Perplexity 12.7805
# Step 500: Train loss 2.5259, Val loss 2.5268, Perplexity 12.5134
# Step 600: Train loss 2.5040, Val loss 2.5062, Perplexity 12.2581
# Step 700: Train loss 2.4864, Val loss 2.4924, Perplexity 12.0902
# Step 800: Train loss 2.4466, Val loss 2.4516, Perplexity 11.6067
# Step 900: Train loss 2.4158, Val loss 2.4217, Perplexity 11.2647
# Step 1000: Train loss 2.3755, Val loss 2.3882, Perplexity 10.8940
# Step 1100: Train loss 2.3499, Val loss 2.3632, Perplexity 10.6250
# Step 1200: Train loss 2.3228, Val loss 2.3435, Perplexity 10.4178
# Step 1300: Train loss 2.2936, Val loss 2.3105, Perplexity 10.0795
# Step 1400: Train loss 2.2796, Val loss 2.2965, Perplexity 9.9389
# Step 1500: Train loss 2.2580, Val loss 2.2737, Perplexity 9.7157
# Step 1600: Train loss 2.2338, Val loss 2.2587, Perplexity 9.5702
# Step 1700: Train loss 2.2197, Val loss 2.2426, Perplexity 9.4177
# Step 1800: Train loss 2.2021, Val loss 2.2267, Perplexity 9.2696
# Step 1900: Train loss 2.1791, Val loss 2.2031, Perplexity 9.0528
# Step 2000: Train loss 2.1667, Val loss 2.1977, Perplexity 9.0046
# Step 2100: Train loss 2.1513, Val loss 2.1842, Perplexity 8.8835
# Step 2200: Train loss 2.1284, Val loss 2.1613, Perplexity 8.6825
# Step 2300: Train loss 2.1178, Val loss 2.1514, Perplexity 8.5969
# Step 2400: Train loss 2.0990, Val loss 2.1342, Perplexity 8.4505
# Step 2500: Train loss 2.0890, Val loss 2.1246, Perplexity 8.3693
# Step 2600: Train loss 2.0756, Val loss 2.1081, Perplexity 8.2326
# Step 2700: Train loss 2.0601, Val loss 2.0948, Perplexity 8.1238
# Step 2800: Train loss 2.0462, Val loss 2.0911, Perplexity 8.0939
# Step 2900: Train loss 2.0367, Val loss 2.0763, Perplexity 7.9753
# Step 3000: Train loss 2.0257, Val loss 2.0706, Perplexity 7.9295
# Step 3100: Train loss 2.0206, Val loss 2.0702, Perplexity 7.9267
# Step 3200: Train loss 2.0075, Val loss 2.0474, Perplexity 7.7477
# Step 3300: Train loss 1.9987, Val loss 2.0405, Perplexity 7.6942
# Step 3400: Train loss 1.9872, Val loss 2.0317, Perplexity 7.6271
# Step 3500: Train loss 1.9785, Val loss 2.0296, Perplexity 7.6111
# Step 3600: Train loss 1.9748, Val loss 2.0161, Perplexity 7.5087
# Step 3700: Train loss 1.9680, Val loss 2.0123, Perplexity 7.4807
# Step 3800: Train loss 1.9628, Val loss 2.0115, Perplexity 7.4747
# Step 3900: Train loss 1.9492, Val loss 2.0024, Perplexity 7.4070
# Step 4000: Train loss 1.9475, Val loss 2.0026, Perplexity 7.4083
# Step 4100: Train loss 1.9310, Val loss 1.9867, Perplexity 7.2912
# Step 4200: Train loss 1.9340, Val loss 1.9882, Perplexity 7.3023
# Step 4300: Train loss 1.9200, Val loss 1.9736, Perplexity 7.1963
# Step 4400: Train loss 1.9151, Val loss 1.9742, Perplexity 7.2011
# Step 4500: Train loss 1.9140, Val loss 1.9722, Perplexity 7.1867
# Step 4600: Train loss 1.9036, Val loss 1.9609, Perplexity 7.1055
# Step 4700: Train loss 1.8993, Val loss 1.9608, Perplexity 7.1049
# Step 4800: Train loss 1.8982, Val loss 1.9506, Perplexity 7.0329
# Step 4900: Train loss 1.8921, Val loss 1.9483, Perplexity 7.0164
# Step 5000: Train loss 1.8912, Val loss 1.9519, Perplexity 7.0424
# Step 5100: Train loss 1.8860, Val loss 1.9443, Perplexity 6.9886
# Step 5200: Train loss 1.8755, Val loss 1.9403, Perplexity 6.9608
# Step 5300: Train loss 1.8767, Val loss 1.9390, Perplexity 6.9517
# Step 5400: Train loss 1.8751, Val loss 1.9313, Perplexity 6.8982
# Step 5500: Train loss 1.8685, Val loss 1.9335, Perplexity 6.9137
# Step 5600: Train loss 1.8627, Val loss 1.9287, Perplexity 6.8802
# Step 5700: Train loss 1.8577, Val loss 1.9230, Perplexity 6.8415
# Step 5800: Train loss 1.8544, Val loss 1.9195, Perplexity 6.8174
# Step 5900: Train loss 1.8522, Val loss 1.9202, Perplexity 6.8225
# Step 6000: Train loss 1.8500, Val loss 1.9148, Perplexity 6.7853
# Step 6100: Train loss 1.8442, Val loss 1.9082, Perplexity 6.7410
# Step 6200: Train loss 1.8407, Val loss 1.9100, Perplexity 6.7534
# Step 6300: Train loss 1.8328, Val loss 1.9062, Perplexity 6.7278
# Step 6400: Train loss 1.8366, Val loss 1.9046, Perplexity 6.7171
# Step 6500: Train loss 1.8280, Val loss 1.9008, Perplexity 6.6909
# Step 6600: Train loss 1.8239, Val loss 1.8977, Perplexity 6.6707
# Step 6700: Train loss 1.8210, Val loss 1.8921, Perplexity 6.6332
# Step 6800: Train loss 1.8214, Val loss 1.8925, Perplexity 6.6362
# Step 6900: Train loss 1.8169, Val loss 1.8868, Perplexity 6.5983
# Step 7000: Train loss 1.8179, Val loss 1.8896, Perplexity 6.6169
# Step 7100: Train loss 1.8131, Val loss 1.8878, Perplexity 6.6048
# Step 7200: Train loss 1.8075, Val loss 1.8810, Perplexity 6.5598
# Step 7300: Train loss 1.8091, Val loss 1.8875, Perplexity 6.6027
# Step 7400: Train loss 1.8013, Val loss 1.8808, Perplexity 6.5586
# Step 7500: Train loss 1.8035, Val loss 1.8755, Perplexity 6.5242
# Step 7600: Train loss 1.7997, Val loss 1.8805, Perplexity 6.5568
# Step 7700: Train loss 1.7960, Val loss 1.8806, Perplexity 6.5572
# Step 7800: Train loss 1.7935, Val loss 1.8670, Perplexity 6.4690
# Step 7900: Train loss 1.7938, Val loss 1.8742, Perplexity 6.5157
# Step 8000: Train loss 1.7968, Val loss 1.8772, Perplexity 6.5355
# Step 8100: Train loss 1.7881, Val loss 1.8635, Perplexity 6.4463
# Step 8200: Train loss 1.7891, Val loss 1.8719, Perplexity 6.5004
# Step 8300: Train loss 1.7776, Val loss 1.8659, Perplexity 6.4620
# Step 8400: Train loss 1.7838, Val loss 1.8586, Perplexity 6.4145
# Step 8500: Train loss 1.7791, Val loss 1.8659, Perplexity 6.4615
# Step 8600: Train loss 1.7777, Val loss 1.8628, Perplexity 6.4418
# Step 8700: Train loss 1.7772, Val loss 1.8613, Perplexity 6.4318
# Step 8800: Train loss 1.7737, Val loss 1.8558, Perplexity 6.3967
# Step 8900: Train loss 1.7731, Val loss 1.8539, Perplexity 6.3847
# Step 9000: Train loss 1.7715, Val loss 1.8535, Perplexity 6.3819
# Step 9100: Train loss 1.7672, Val loss 1.8501, Perplexity 6.3605
# Step 9200: Train loss 1.7651, Val loss 1.8488, Perplexity 6.3519
# Step 9300: Train loss 1.7614, Val loss 1.8501, Perplexity 6.3607
# Step 9400: Train loss 1.7618, Val loss 1.8453, Perplexity 6.3299
# Step 9500: Train loss 1.7589, Val loss 1.8492, Perplexity 6.3545
# Step 9600: Train loss 1.7563, Val loss 1.8439, Perplexity 6.3210
# Step 9700: Train loss 1.7550, Val loss 1.8459, Perplexity 6.3341
# Step 9800: Train loss 1.7513, Val loss 1.8416, Perplexity 6.3064
# Step 9900: Train loss 1.7528, Val loss 1.8424, Perplexity 6.3116
# Step 9999: Train loss 1.7548, Val loss 1.8429, Perplexity 6.3148
