# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import matplotlib.pyplot as plt
import os

# hyperparameters
batch_size = 256
block_size = 128
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.1

# dynamic block_size adjustment for GPU memory
#if device == 'cuda':
#device = "cuda"
#gpu_memory = torch.cuda.get_device_properties(0).total_memory
#block_size = min(128, max(16, gpu_memory // (n_embd * 1024)))

print(block_size)
torch.manual_seed(166045)

# Load text data
with open('pan-tadeusz.txt', 'r', encoding='utf-8') as f:
    text = f.read()

chars = sorted(list(set(text)))
vocab_size = len(chars)
stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for i, ch in enumerate(chars)}
encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join([itos[i] for i in l])

data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

def get_batch(split, seq_sampling=False):
    data = train_data if split == 'train' else val_data
    if seq_sampling:
        start_idx = torch.randint(0, len(data) - block_size, (1,)).item()
        x = data[start_idx:start_idx + block_size].unsqueeze(0).repeat(batch_size, 1)
        y = data[start_idx + 1:start_idx + block_size + 1].unsqueeze(0).repeat(batch_size, 1)
    else:
        ix = torch.randint(len(data) - block_size, (batch_size,))
        x = torch.stack([data[i:i + block_size] for i in ix])
        y = torch.stack([data[i + 1:i + block_size + 1] for i in ix])
    return x.to(device), y.to(device)

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)
        wei = q @ k.transpose(-2, -1) * C**-0.5
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        out = wei @ v
        return out

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedForward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.dropout = nn.Dropout(0.1)

    def forward(self, x):
        x = x + self.dropout(self.sa(self.ln1(x)))
        x = x + self.dropout(self.ffwd(self.ln2(x)))
        return x

class GPTModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = tok_emb + pos_emb
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B * T, C)
            targets = targets.view(B * T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens, temperature=1.0):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, _ = self(idx_cond)
            logits = logits[:, -1, :] / temperature
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx


def calculate_perplexity(logits, targets):
    # Przekształć logits na logarytmy prawdopodobieństw (softmax + log)
    log_probs = F.log_softmax(logits, dim=-1)

    # Spłaszcz targets do wymiaru 1D, aby pasował do logits
    targets = targets.view(-1)

    # Wybierz logarytmy prawdopodobieństw odpowiadające poprawnym tokenom (targets)
    log_probs_target = log_probs[torch.arange(logits.size(0)), targets]

    # Oblicz średni logarytm prawdopodobieństwa na token
    mean_log_prob = log_probs_target.mean()

    # Oblicz perplexity na podstawie wzoru
    perplexity = torch.exp(-mean_log_prob).item()

    return perplexity





model = GPTModel().to(device)
print(sum(p.numel() for p in model.parameters()) / 1e6, 'M parameters')

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

# Lists to store metrics
train_losses, val_losses, perplexities_train, perplexities_val = [], [], [], []

# Training loop
for iter in range(max_iters):
    # Collect training metrics for every iteration
    xb, yb = get_batch('train')
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

    # Save training loss and perplexity for every iteration
    train_losses.append(loss.item())
    perplexities_train.append(calculate_perplexity(logits, yb))

    # Collect validation metrics for every iteration
    X_val, Y_val = get_batch('val')
    logits_val, _ = model(X_val, Y_val)
    val_loss = F.cross_entropy(logits_val.view(-1, logits_val.size(-1)), Y_val.view(-1)).item()
    val_losses.append(val_loss)
    perplexity_val = calculate_perplexity(logits_val, Y_val)
    perplexities_val.append(perplexity_val)

    # Print metrics at eval_interval or the last iteration
    if iter % eval_interval == 0 or iter == max_iters - 1:
        print(f"step {iter}: train loss {train_losses[-1]:.4f}, val loss {val_losses[-1]:.4f}, "
              f"train perplexity {perplexities_train[-1]:.4f}, val perplexity {perplexity_val:.4f}")

import matplotlib.pyplot as plt
import torch

# Create the directory if it doesn't exist
output_dir = "wykresy"
os.makedirs(output_dir, exist_ok=True)

# Plot training and validation perplexity on the same graph
plt.figure()
plt.plot(perplexities_train, label='Nieokreśloność zbiór treningowy', color='blue')
plt.plot(perplexities_val, label='Nieokreśloność zbiór walidacyjny', color='orange')
plt.legend()
plt.xlabel('Epoka')
plt.ylabel('Nieokreśloność')
plt.title('Porównanie: zbiór treningowy vs walidacyjny')
# Save the plot
plt.savefig(os.path.join(output_dir, f'nieokreslonosc_{batch_size}.png'))
plt.close()

# Plot training loss
plt.figure()
plt.plot(train_losses, label='Strata zbiór treningowy', color='blue')
plt.legend()
plt.xlabel('Iteracja')
plt.ylabel('Strata')
plt.title('Strata treningowa w czasie')
# Save the plot
plt.savefig(os.path.join(output_dir, f'strata_treningowa_{batch_size}.png'))
plt.close()

# Plot validation loss
plt.figure()
plt.plot(val_losses, label='Strata zbiór walidacyjny', color='orange')
plt.legend()
plt.xlabel('Iteracja')
plt.ylabel('Strata')
plt.title('Strata walidacyjna w czasie')
# Save the plot
plt.savefig(os.path.join(output_dir, f'strata_walidacyjna_{batch_size}.png'))
plt.close()

# Generate text
context = torch.zeros((1, 1), dtype=torch.long, device=device)
generated_text = decode(model.generate(context, max_new_tokens=2000)[0].tolist())

# Save generated text to a file
with open(f'wygenerowany_tekst_{batch_size}.txt', 'w', encoding='utf-8') as f:
    f.write(generated_text)
# Out:
# 128
# 0.218324 M parameters
# step 0: train loss 4.6683, val loss 4.4598, train perplexity 106.5159, val perplexity 86.4681
# step 100: train loss 2.6914, val loss 2.7085, train perplexity 14.7526, val perplexity 15.0074
# step 200: train loss 2.5951, val loss 2.5932, train perplexity 13.3979, val perplexity 13.3724
# step 300: train loss 2.5513, val loss 2.5440, train perplexity 12.8239, val perplexity 12.7303
# step 400: train loss 2.5020, val loss 2.5148, train perplexity 12.2071, val perplexity 12.3640
# step 500: train loss 2.4604, val loss 2.4649, train perplexity 11.7095, val perplexity 11.7627
# step 600: train loss 2.4048, val loss 2.4077, train perplexity 11.0759, val perplexity 11.1086
# step 700: train loss 2.3539, val loss 2.3662, train perplexity 10.5266, val perplexity 10.6571
# step 800: train loss 2.3147, val loss 2.3257, train perplexity 10.1221, val perplexity 10.2342
# step 900: train loss 2.2565, val loss 2.2663, train perplexity 9.5500, val perplexity 9.6433
# step 1000: train loss 2.2279, val loss 2.2505, train perplexity 9.2800, val perplexity 9.4924
# step 1100: train loss 2.1824, val loss 2.2051, train perplexity 8.8673, val perplexity 9.0711
# step 1200: train loss 2.1584, val loss 2.1948, train perplexity 8.6575, val perplexity 8.9778
# step 1300: train loss 2.1289, val loss 2.1669, train perplexity 8.4059, val perplexity 8.7311
# step 1400: train loss 2.0920, val loss 2.1413, train perplexity 8.1012, val perplexity 8.5105
# step 1500: train loss 2.0769, val loss 2.1268, train perplexity 7.9799, val perplexity 8.3879
# step 1600: train loss 2.0718, val loss 2.1024, train perplexity 7.9395, val perplexity 8.1858
# step 1700: train loss 2.0458, val loss 2.0922, train perplexity 7.7353, val perplexity 8.1029
# step 1800: train loss 2.0265, val loss 2.0577, train perplexity 7.5872, val perplexity 7.8283
# step 1900: train loss 2.0041, val loss 2.0525, train perplexity 7.4194, val perplexity 7.7870
# step 2000: train loss 2.0044, val loss 2.0515, train perplexity 7.4219, val perplexity 7.7799
# step 2100: train loss 1.9839, val loss 2.0549, train perplexity 7.2711, val perplexity 7.8058
# step 2200: train loss 1.9855, val loss 2.0212, train perplexity 7.2830, val perplexity 7.5476
# step 2300: train loss 1.9667, val loss 2.0390, train perplexity 7.1469, val perplexity 7.6830
# step 2400: train loss 1.9690, val loss 2.0362, train perplexity 7.1637, val perplexity 7.6616
# step 2500: train loss 1.9448, val loss 2.0183, train perplexity 6.9923, val perplexity 7.5257
# step 2600: train loss 1.9364, val loss 2.0188, train perplexity 6.9336, val perplexity 7.5295
# step 2700: train loss 1.9239, val loss 1.9969, train perplexity 6.8474, val perplexity 7.3664
# step 2800: train loss 1.9144, val loss 1.9964, train perplexity 6.7827, val perplexity 7.3625
# step 2900: train loss 1.9048, val loss 1.9706, train perplexity 6.7184, val perplexity 7.1750
# step 3000: train loss 1.9139, val loss 1.9854, train perplexity 6.7797, val perplexity 7.2818
# step 3100: train loss 1.8991, val loss 1.9652, train perplexity 6.6801, val perplexity 7.1361
# step 3200: train loss 1.8947, val loss 1.9648, train perplexity 6.6504, val perplexity 7.1338
# step 3300: train loss 1.8779, val loss 1.9486, train perplexity 6.5400, val perplexity 7.0191
# step 3400: train loss 1.8867, val loss 1.9553, train perplexity 6.5974, val perplexity 7.0662
# step 3500: train loss 1.8666, val loss 1.9470, train perplexity 6.4662, val perplexity 7.0079
# step 3600: train loss 1.8546, val loss 1.9746, train perplexity 6.3892, val perplexity 7.2040
# step 3700: train loss 1.8649, val loss 1.9415, train perplexity 6.4552, val perplexity 6.9692
# step 3800: train loss 1.8482, val loss 1.9486, train perplexity 6.3486, val perplexity 7.0190
# step 3900: train loss 1.8593, val loss 1.9344, train perplexity 6.4193, val perplexity 6.9199
# step 4000: train loss 1.8546, val loss 1.9325, train perplexity 6.3893, val perplexity 6.9069
# step 4100: train loss 1.8309, val loss 1.9427, train perplexity 6.2397, val perplexity 6.9778
# step 4200: train loss 1.8272, val loss 1.9200, train perplexity 6.2167, val perplexity 6.8212
# step 4300: train loss 1.8396, val loss 1.9402, train perplexity 6.2938, val perplexity 6.9599
# step 4400: train loss 1.8321, val loss 1.9266, train perplexity 6.2471, val perplexity 6.8664
# step 4500: train loss 1.8283, val loss 1.9223, train perplexity 6.2233, val perplexity 6.8368
# step 4600: train loss 1.8313, val loss 1.9184, train perplexity 6.2419, val perplexity 6.8103
# step 4700: train loss 1.8121, val loss 1.8955, train perplexity 6.1232, val perplexity 6.6557
# step 4800: train loss 1.8120, val loss 1.9095, train perplexity 6.1226, val perplexity 6.7500
# step 4900: train loss 1.8300, val loss 1.8976, train perplexity 6.2337, val perplexity 6.6697
# step 5000: train loss 1.8209, val loss 1.9124, train perplexity 6.1774, val perplexity 6.7692
# step 5100: train loss 1.8290, val loss 1.8956, train perplexity 6.2276, val perplexity 6.6566
# step 5200: train loss 1.8159, val loss 1.8986, train perplexity 6.1468, val perplexity 6.6767
# step 5300: train loss 1.7940, val loss 1.8932, train perplexity 6.0134, val perplexity 6.6407
# step 5400: train loss 1.7895, val loss 1.9065, train perplexity 5.9868, val perplexity 6.7292
# step 5500: train loss 1.7998, val loss 1.9090, train perplexity 6.0481, val perplexity 6.7462
# step 5600: train loss 1.7939, val loss 1.8923, train perplexity 6.0127, val perplexity 6.6344
# step 5700: train loss 1.7875, val loss 1.8806, train perplexity 5.9745, val perplexity 6.5573
# step 5800: train loss 1.7885, val loss 1.8973, train perplexity 5.9803, val perplexity 6.6680
# step 5900: train loss 1.7956, val loss 1.8692, train perplexity 6.0233, val perplexity 6.4828
# step 6000: train loss 1.7966, val loss 1.8774, train perplexity 6.0291, val perplexity 6.5364
# step 6100: train loss 1.7686, val loss 1.8829, train perplexity 5.8628, val perplexity 6.5727
# step 6200: train loss 1.7841, val loss 1.8654, train perplexity 5.9541, val perplexity 6.4582
# step 6300: train loss 1.7690, val loss 1.8822, train perplexity 5.8652, val perplexity 6.5682
# step 6400: train loss 1.7838, val loss 1.8695, train perplexity 5.9523, val perplexity 6.4848
# step 6500: train loss 1.7774, val loss 1.8564, train perplexity 5.9148, val perplexity 6.4004
# step 6600: train loss 1.7771, val loss 1.8786, train perplexity 5.9125, val perplexity 6.5445
# step 6700: train loss 1.7688, val loss 1.8657, train perplexity 5.8637, val perplexity 6.4608
# step 6800: train loss 1.7464, val loss 1.8665, train perplexity 5.7342, val perplexity 6.4656
# step 6900: train loss 1.7553, val loss 1.8659, train perplexity 5.7854, val perplexity 6.4621
# step 7000: train loss 1.7554, val loss 1.8631, train perplexity 5.7859, val perplexity 6.4436
# step 7100: train loss 1.7625, val loss 1.8661, train perplexity 5.8271, val perplexity 6.4629
# step 7200: train loss 1.7638, val loss 1.8739, train perplexity 5.8345, val perplexity 6.5139
# step 7300: train loss 1.7534, val loss 1.8722, train perplexity 5.7744, val perplexity 6.5029
# step 7400: train loss 1.7387, val loss 1.8540, train perplexity 5.6899, val perplexity 6.3853
# step 7500: train loss 1.7602, val loss 1.8712, train perplexity 5.8138, val perplexity 6.4960
# step 7600: train loss 1.7661, val loss 1.8633, train perplexity 5.8481, val perplexity 6.4447
# step 7700: train loss 1.7402, val loss 1.8500, train perplexity 5.6987, val perplexity 6.3596
# step 7800: train loss 1.7296, val loss 1.8556, train perplexity 5.6382, val perplexity 6.3957
# step 7900: train loss 1.7361, val loss 1.8547, train perplexity 5.6753, val perplexity 6.3901
# step 8000: train loss 1.7300, val loss 1.8563, train perplexity 5.6404, val perplexity 6.4003
# step 8100: train loss 1.7388, val loss 1.8324, train perplexity 5.6907, val perplexity 6.2489
# step 8200: train loss 1.7294, val loss 1.8503, train perplexity 5.6372, val perplexity 6.3614
# step 8300: train loss 1.7208, val loss 1.8242, train perplexity 5.5890, val perplexity 6.1977
# step 8400: train loss 1.7450, val loss 1.8429, train perplexity 5.7258, val perplexity 6.3146
# step 8500: train loss 1.7428, val loss 1.8702, train perplexity 5.7131, val perplexity 6.4894
# step 8600: train loss 1.7376, val loss 1.8522, train perplexity 5.6834, val perplexity 6.3739
# step 8700: train loss 1.7157, val loss 1.8414, train perplexity 5.5604, val perplexity 6.3054
# step 8800: train loss 1.7270, val loss 1.8542, train perplexity 5.6240, val perplexity 6.3865
# step 8900: train loss 1.7351, val loss 1.8369, train perplexity 5.6694, val perplexity 6.2771
# step 9000: train loss 1.7430, val loss 1.8377, train perplexity 5.7146, val perplexity 6.2820
# step 9100: train loss 1.7273, val loss 1.8304, train perplexity 5.6257, val perplexity 6.2365
# step 9200: train loss 1.7313, val loss 1.8336, train perplexity 5.6479, val perplexity 6.2564
# step 9300: train loss 1.7288, val loss 1.8590, train perplexity 5.6337, val perplexity 6.4174
# step 9400: train loss 1.7310, val loss 1.8252, train perplexity 5.6462, val perplexity 6.2037
# step 9500: train loss 1.6980, val loss 1.8633, train perplexity 5.4629, val perplexity 6.4449
# step 9600: train loss 1.7075, val loss 1.8381, train perplexity 5.5151, val perplexity 6.2848
# step 9700: train loss 1.7149, val loss 1.8451, train perplexity 5.5559, val perplexity 6.3289
# step 9800: train loss 1.7031, val loss 1.8513, train perplexity 5.4910, val perplexity 6.3683
# step 9900: train loss 1.7263, val loss 1.8354, train perplexity 5.6200, val perplexity 6.2679
# step 9999: train loss 1.7098, val loss 1.8270, train perplexity 5.5277, val perplexity 6.2150
