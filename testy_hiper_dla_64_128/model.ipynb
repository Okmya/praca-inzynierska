# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import matplotlib.pyplot as plt

# hyperparameters
batch_size = 256 
block_size = 64
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.1

# dynamic block_size adjustment for GPU memory
#if device == 'cuda':
#device = "cuda"
gpu_memory = torch.cuda.get_device_properties(0).total_memory
block_size = min(128, max(16, gpu_memory // (n_embd * 1024)))

torch.manual_seed(166045)

# Load text data
with open('pan-tadeusz.txt', 'r', encoding='utf-8') as f:
    text = f.read()

chars = sorted(list(set(text)))
vocab_size = len(chars)
stoi = {ch: i for i, ch in enumerate(chars)}
itos = {i: ch for i, ch in enumerate(chars)}
encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join([itos[i] for i in l])

data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

def get_batch(split, seq_sampling=False):
    data = train_data if split == 'train' else val_data
    if seq_sampling:
        start_idx = torch.randint(0, len(data) - block_size, (1,)).item()
        x = data[start_idx:start_idx + block_size].unsqueeze(0).repeat(batch_size, 1)
        y = data[start_idx + 1:start_idx + block_size + 1].unsqueeze(0).repeat(batch_size, 1)
    else:
        ix = torch.randint(len(data) - block_size, (batch_size,))
        x = torch.stack([data[i:i + block_size] for i in ix])
        y = torch.stack([data[i + 1:i + block_size + 1] for i in ix])
    return x.to(device), y.to(device)

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)
        wei = q @ k.transpose(-2, -1) * C**-0.5
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)
        v = self.value(x)
        out = wei @ v
        return out

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedForward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)
        self.dropout = nn.Dropout(0.1)

    def forward(self, x):
        x = x + self.dropout(self.sa(self.ln1(x)))
        x = x + self.dropout(self.ffwd(self.ln2(x)))
        return x

class GPTModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = tok_emb + pos_emb
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B * T, C)
            targets = targets.view(B * T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens, temperature=1.0):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, _ = self(idx_cond)
            logits = logits[:, -1, :] / temperature
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx


def calculate_perplexity(logits, targets):
    # Przekształć logits na logarytmy prawdopodobieństw (softmax + log)
    log_probs = F.log_softmax(logits, dim=-1)

    # Spłaszcz targets do wymiaru 1D, aby pasował do logits
    targets = targets.view(-1)

    # Wybierz logarytmy prawdopodobieństw odpowiadające poprawnym tokenom (targets)
    log_probs_target = log_probs[torch.arange(logits.size(0)), targets]

    # Oblicz średni logarytm prawdopodobieństwa na token
    mean_log_prob = log_probs_target.mean()

    # Oblicz perplexity na podstawie wzoru
    perplexity = torch.exp(-mean_log_prob).item()

    return perplexity





model = GPTModel().to(device)
print(sum(p.numel() for p in model.parameters()) / 1e6, 'M parameters')

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

train_losses, val_losses, perplexities_train,perplexities_val = [], [], [], []


# Training loop
for iter in range(max_iters):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        train_losses.append(losses['train'])
        val_losses.append(losses['val'])

        # Calculate perplexity for validation set
        X_val, Y_val = get_batch('val')
        logits_val, _ = model(X_val, Y_val)
        perplexity_val = calculate_perplexity(logits_val, Y_val)
        perplexities_val.append(perplexity_val)

        # Calculate perplexity for training set
        X_train, Y_train = get_batch('train')
        logits_train, _ = model(X_train, Y_train)
        perplexity_train = calculate_perplexity(logits_train, Y_train)
        perplexities_train.append(perplexity_train)

        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}, "
              f"train perplexity {perplexity_train:.4f}, val perplexity {perplexity_val:.4f}")

    xb, yb = get_batch('train')
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# Plot training and validation perplexity on the same graph
plt.figure()
plt.plot(perplexities_train, label='Train Perplexity')
plt.plot(perplexities_val, label='Validation Perplexity')
plt.legend()
plt.xlabel('Evaluation Interval')
plt.ylabel('Perplexity')
plt.title('Train vs Validation Perplexity over Time')
plt.show()

# Plot training loss
plt.figure()
plt.plot(train_losses, label='Train Loss')
plt.legend()
plt.xlabel('Evaluation Interval')
plt.ylabel('Loss')
plt.title('Training Loss over Time')
plt.show()

# Plot validation loss
plt.figure()
plt.plot(val_losses, label='Validation Loss')
plt.legend()
plt.xlabel('Evaluation Interval')
plt.ylabel('Loss')
plt.title('Validation Loss over Time')
plt.show()

# Generate text
context = torch.zeros((1, 1), dtype=torch.long, device=device)
generated_text = decode(model.generate(context, max_new_tokens=2000)[0].tolist())

# Save generated text to a file
with open('generated_text.txt', 'w', encoding='utf-8') as f:
    f.write(generated_text)
# Out:
# 0.218195 M parameters
# step 0: train loss 4.5741, val loss 4.5727, train perplexity 96.9771, val perplexity 96.7334
# step 100: train loss 2.6763, val loss 2.6693, train perplexity 14.7483, val perplexity 14.5993
# step 200: train loss 2.5687, val loss 2.5670, train perplexity 13.2811, val perplexity 13.3111
# step 300: train loss 2.5215, val loss 2.5218, train perplexity 12.7978, val perplexity 12.7055
# step 400: train loss 2.4766, val loss 2.4806, train perplexity 12.1808, val perplexity 12.1762
# step 500: train loss 2.4125, val loss 2.4212, train perplexity 11.6094, val perplexity 11.7330
# step 600: train loss 2.3415, val loss 2.3557, train perplexity 10.9839, val perplexity 10.9422
# step 700: train loss 2.2739, val loss 2.2931, train perplexity 10.2791, val perplexity 10.5472
# step 800: train loss 2.2192, val loss 2.2446, train perplexity 9.7049, val perplexity 10.0201
# step 900: train loss 2.1652, val loss 2.1902, train perplexity 9.2676, val perplexity 9.6919
# step 1000: train loss 2.1172, val loss 2.1513, train perplexity 8.9812, val perplexity 9.2959
# step 1100: train loss 2.0806, val loss 2.1202, train perplexity 8.8749, val perplexity 9.0713
# step 1200: train loss 2.0414, val loss 2.0851, train perplexity 8.4652, val perplexity 8.8214
# step 1300: train loss 2.0077, val loss 2.0521, train perplexity 8.0514, val perplexity 8.3877
# step 1400: train loss 1.9809, val loss 2.0288, train perplexity 8.0468, val perplexity 8.3455
# step 1500: train loss 1.9547, val loss 2.0055, train perplexity 7.8705, val perplexity 8.0239
# step 1600: train loss 1.9370, val loss 1.9923, train perplexity 7.6029, val perplexity 8.1713
# step 1700: train loss 1.9178, val loss 1.9754, train perplexity 7.5198, val perplexity 7.9527
# step 1800: train loss 1.9015, val loss 1.9605, train perplexity 7.4716, val perplexity 7.9201
# step 1900: train loss 1.8839, val loss 1.9479, train perplexity 7.3201, val perplexity 7.7421
# step 2000: train loss 1.8710, val loss 1.9348, train perplexity 7.2041, val perplexity 7.5792
# step 2100: train loss 1.8559, val loss 1.9269, train perplexity 7.2563, val perplexity 7.5328
# step 2200: train loss 1.8451, val loss 1.9134, train perplexity 7.1711, val perplexity 7.5455
# step 2300: train loss 1.8338, val loss 1.9048, train perplexity 6.9990, val perplexity 7.3494
# step 2400: train loss 1.8232, val loss 1.8979, train perplexity 6.9173, val perplexity 7.4021
# step 2500: train loss 1.8128, val loss 1.8906, train perplexity 6.8931, val perplexity 7.4250
# step 2600: train loss 1.8039, val loss 1.8807, train perplexity 6.8240, val perplexity 7.2233
# step 2700: train loss 1.7948, val loss 1.8744, train perplexity 6.6675, val perplexity 7.3809
# step 2800: train loss 1.7856, val loss 1.8675, train perplexity 6.7122, val perplexity 7.2239
# step 2900: train loss 1.7785, val loss 1.8637, train perplexity 6.6300, val perplexity 7.1688
# step 3000: train loss 1.7709, val loss 1.8516, train perplexity 6.4677, val perplexity 6.9000
# step 3100: train loss 1.7616, val loss 1.8463, train perplexity 6.6077, val perplexity 6.9438
# step 3200: train loss 1.7573, val loss 1.8465, train perplexity 6.4897, val perplexity 7.0790
# step 3300: train loss 1.7509, val loss 1.8387, train perplexity 6.4293, val perplexity 7.0127
# step 3400: train loss 1.7442, val loss 1.8331, train perplexity 6.4151, val perplexity 6.9688
# step 3500: train loss 1.7400, val loss 1.8279, train perplexity 6.3891, val perplexity 6.9933
# step 3600: train loss 1.7322, val loss 1.8204, train perplexity 6.3964, val perplexity 6.9547
# step 3700: train loss 1.7282, val loss 1.8211, train perplexity 6.3777, val perplexity 6.7975
# step 3800: train loss 1.7215, val loss 1.8148, train perplexity 6.3318, val perplexity 6.8675
# step 3900: train loss 1.7150, val loss 1.8127, train perplexity 6.2664, val perplexity 7.0011
# step 4000: train loss 1.7100, val loss 1.8069, train perplexity 6.2501, val perplexity 6.8020
# step 4100: train loss 1.7059, val loss 1.8012, train perplexity 6.2315, val perplexity 6.7936
# step 4200: train loss 1.7002, val loss 1.8003, train perplexity 6.2760, val perplexity 6.9074
# step 4300: train loss 1.6985, val loss 1.7950, train perplexity 6.2286, val perplexity 6.7188
# step 4400: train loss 1.6940, val loss 1.7938, train perplexity 6.1148, val perplexity 6.6447
# step 4500: train loss 1.6907, val loss 1.7896, train perplexity 6.2010, val perplexity 6.7599
# step 4600: train loss 1.6873, val loss 1.7897, train perplexity 6.0601, val perplexity 6.5723
# step 4700: train loss 1.6820, val loss 1.7871, train perplexity 6.1554, val perplexity 6.7501
# step 4800: train loss 1.6778, val loss 1.7855, train perplexity 6.1330, val perplexity 6.6339
# step 4900: train loss 1.6780, val loss 1.7815, train perplexity 6.0812, val perplexity 6.5814
# step 5000: train loss 1.6719, val loss 1.7808, train perplexity 5.9803, val perplexity 6.5227
# step 5100: train loss 1.6686, val loss 1.7754, train perplexity 6.0411, val perplexity 6.5222
# step 5200: train loss 1.6661, val loss 1.7722, train perplexity 6.0357, val perplexity 6.6193
# step 5300: train loss 1.6639, val loss 1.7721, train perplexity 5.9819, val perplexity 6.5542
# step 5400: train loss 1.6572, val loss 1.7686, train perplexity 5.9541, val perplexity 6.4925
# step 5500: train loss 1.6563, val loss 1.7692, train perplexity 5.9929, val perplexity 6.6383
# step 5600: train loss 1.6526, val loss 1.7655, train perplexity 6.0233, val perplexity 6.5019
# step 5700: train loss 1.6494, val loss 1.7646, train perplexity 5.8862, val perplexity 6.5822
# step 5800: train loss 1.6497, val loss 1.7667, train perplexity 5.8858, val perplexity 6.4737
# step 5900: train loss 1.6466, val loss 1.7650, train perplexity 5.9390, val perplexity 6.6486
# step 6000: train loss 1.6452, val loss 1.7622, train perplexity 5.7839, val perplexity 6.3277
# step 6100: train loss 1.6434, val loss 1.7608, train perplexity 5.8623, val perplexity 6.5557
# step 6200: train loss 1.6380, val loss 1.7574, train perplexity 5.8224, val perplexity 6.5411
# step 6300: train loss 1.6342, val loss 1.7509, train perplexity 5.8808, val perplexity 6.4015
# step 6400: train loss 1.6327, val loss 1.7488, train perplexity 5.8350, val perplexity 6.3533
# step 6500: train loss 1.6322, val loss 1.7533, train perplexity 5.7676, val perplexity 6.4477
# step 6600: train loss 1.6298, val loss 1.7491, train perplexity 5.7344, val perplexity 6.3873
# step 6700: train loss 1.6257, val loss 1.7487, train perplexity 5.7826, val perplexity 6.3913
# step 6800: train loss 1.6246, val loss 1.7459, train perplexity 5.8282, val perplexity 6.4530
# step 6900: train loss 1.6214, val loss 1.7435, train perplexity 5.6105, val perplexity 6.4072
# step 7000: train loss 1.6208, val loss 1.7454, train perplexity 5.7708, val perplexity 6.3397
# step 7100: train loss 1.6165, val loss 1.7438, train perplexity 5.8250, val perplexity 6.3778
# step 7200: train loss 1.6166, val loss 1.7397, train perplexity 5.7592, val perplexity 6.2690
# step 7300: train loss 1.6149, val loss 1.7400, train perplexity 5.6613, val perplexity 6.2745
# step 7400: train loss 1.6107, val loss 1.7420, train perplexity 5.6056, val perplexity 6.4334
# step 7500: train loss 1.6125, val loss 1.7443, train perplexity 5.7762, val perplexity 6.3857
# step 7600: train loss 1.6080, val loss 1.7391, train perplexity 5.6331, val perplexity 6.3795
# step 7700: train loss 1.6087, val loss 1.7358, train perplexity 5.7084, val perplexity 6.3705
# step 7800: train loss 1.6065, val loss 1.7353, train perplexity 5.7042, val perplexity 6.4126
# step 7900: train loss 1.6041, val loss 1.7344, train perplexity 5.6655, val perplexity 6.5139
# step 8000: train loss 1.6024, val loss 1.7330, train perplexity 5.6286, val perplexity 6.2066
# step 8100: train loss 1.6001, val loss 1.7308, train perplexity 5.5806, val perplexity 6.4776
# step 8200: train loss 1.5997, val loss 1.7311, train perplexity 5.7135, val perplexity 6.3701
# step 8300: train loss 1.5986, val loss 1.7341, train perplexity 5.7263, val perplexity 6.3895
# step 8400: train loss 1.5966, val loss 1.7307, train perplexity 5.6390, val perplexity 6.3324
# step 8500: train loss 1.5936, val loss 1.7289, train perplexity 5.6292, val perplexity 6.3175
# step 8600: train loss 1.5923, val loss 1.7299, train perplexity 5.6231, val perplexity 6.4979
# step 8700: train loss 1.5926, val loss 1.7279, train perplexity 5.5539, val perplexity 6.3533
# step 8800: train loss 1.5911, val loss 1.7281, train perplexity 5.6701, val perplexity 6.2937
# step 8900: train loss 1.5882, val loss 1.7263, train perplexity 5.6112, val perplexity 6.3332
# step 9000: train loss 1.5869, val loss 1.7233, train perplexity 5.6175, val perplexity 6.2076
# step 9100: train loss 1.5848, val loss 1.7245, train perplexity 5.5459, val perplexity 6.2069
# step 9200: train loss 1.5848, val loss 1.7215, train perplexity 5.6016, val perplexity 6.1961
# step 9300: train loss 1.5851, val loss 1.7228, train perplexity 5.5351, val perplexity 6.2971
# step 9400: train loss 1.5799, val loss 1.7238, train perplexity 5.5715, val perplexity 6.2317
# step 9500: train loss 1.5797, val loss 1.7208, train perplexity 5.4941, val perplexity 6.2322
# step 9600: train loss 1.5777, val loss 1.7186, train perplexity 5.5172, val perplexity 6.1818
# step 9700: train loss 1.5789, val loss 1.7206, train perplexity 5.5994, val perplexity 6.3483
# step 9800: train loss 1.5744, val loss 1.7173, train perplexity 5.5810, val perplexity 6.1996
# step 9900: train loss 1.5766, val loss 1.7143, train perplexity 5.5077, val perplexity 6.1140
# step 9999: train loss 1.5740, val loss 1.7136, train perplexity 5.4663, val perplexity 6.2458
